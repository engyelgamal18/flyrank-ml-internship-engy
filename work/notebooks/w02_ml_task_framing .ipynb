# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/engyelgamal18/flyrank-ml-internship-engy/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# My lane is a ranking/scoring task because the goal is to prioritize content pages and decide which ones should be reviewed first. The model would assign a priority score to each page based on several signals,  then rank the pages from highest to lowest piority.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target/proxy is wether a content page is declining. In the starter dataset, this is represented by is_declining_label. However,this label is derived from trend_direction and trend_pct,so those columus must not to be used as features.The goal is to use other signals avaliable before the outcome to estimate which pages are most likely to need attention.

# %%
target_sketch = {
    "is_declining_label": [1, 0, 1, 0, 1]
}

target_sketch
# Out:
# {'is_declining_label': [1, 0, 1, 0, 1]}

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# My main success metric is precision@50. This measures how many of the top 50 pages ranked by the model are actually declining or need attention.I would consider the model useful if its Precision@50 is clearly better than a simple baseline rule, because a content reviewer has limited time annd needs the highest priority pages to be relevant.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# !git clone https://github.com/engyelgamal18/flyrank-ml-internship-engy.git
# %cd flyrank-ml-internship-engy
# Out:
# Cloning into 'flyrank-ml-internship-engy'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 151 (delta 56), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 1.88 MiB | 9.28 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# /content/flyrank-ml-internship-engy

# %%
# !find data -maxdepth 3 -type f
# Out:
# data/raw/content_refresh_anonymized.csv

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule would be too simple because content priority depends on several signals at the same time such as impressions, CTR, search position, content age and engagement. These signals can interact in different ways so one threshold can not capture every case. Machine learning can combine multiple signals and produce more flexible priority score for deciding which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [*] Every section above is filled — markdown thinking AND the code that backs it
# - [*] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [*] No client names, URLs, or private queries anywhere
# - [*] My claims use careful words: observed, measured, directional, decision-support
# - [*] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
